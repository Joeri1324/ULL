# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
import numpy as np
import marshal
import json

# %%
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def read_simlex(file_name):
    parse_line = lambda line: {'word1': line[0], 'word2': line[1], 'similarity': float(line[3])} if is_number(line[3]) else False

    with open(file_name, 'r') as file:
        return [
            parse_line(line.split())
            for line in file
        ]

def read_analogies(file_name):
    parse_line = lambda line: False if line[0] == ':' else {'a': line[0], 'b': line[1], 'c': line[2], 'd': line[3]}

    with open(file_name, 'r') as file:
        return [
            parse_line(line.split())
            for line in file
        ]

def read_nouns(file_name):
    with open(file_name, 'r') as file:
        return [
            line for line in file
        ]

men = read_men('./MEN/MEN_dataset_lemma_form_full')

# %%
def norm(vector):
    return vector / np.linalg.norm(vector)

def lazy_read(file):
    get_word_and_vector = lambda line: (line[0], [float(x) for x in line[1:]])
    for line in file:
        yield get_word_and_vector(line.split())

def read_from_disk(file_name):
    with open('raw_models/{0}'.format(file_name), 'r') as file:
        words, X = zip(*lazy_read(file))
    return {word: i for i, word in enumerate(words)}, X

def load_model(file_name):
    try:
        with open('pickelled_models/{0}'.format(file_name), 'rb') as file:
            result = marshal.load(file)
            return Model(result['words'], result['X'])
    except:
        words, X = read_from_disk(file_name)
        model = Model(words, X)
        with open('pickelled_models/{0}'.format(file_name), 'wb') as file:
            marshal.dump({'words': words, 'X': X}, file)
        return model

class Model:

    def similarity(self, word1, word2):
        index1, index2 = self.words.get(word1, 0), self.words.get(word2, 0)
        if index1 == 0 or index2 == 0:
            return 0
        vector1 = self.X[index1, :]
        vector2 = self.X[index2, :]
        return (vector1 / np.linalg.norm(vector1)).dot(vector2 / np.linalg.norm(vector2))

    def analogy(self, a, b, c, d):
        index1 = self.words.get(a.lower(), 0)
        index2 = self.words.get(b.lower(), 0)
        index3 = self.words.get(c.lower(), 0)
        if index1 == 0 or index2 == 0 or index3 == 0:
            return 0
        vector1 = self.X[index1, :]
        vector2 = self.X[index2, :]
        vector3 = self.X[index3, :]
        difference_vector = vector2 - vector1
        new_vector = norm(difference_vector)
        indices = np.argsort(self.X.dot(norm(difference_vector + vector3)))
        d_index = self.words.get(d)
        return np.where(indices == d_index)
    
    def get(self, word):
        if not self.words.get(word.lower()):
            return np.zeros(self.X.shape[1])
        return self.X[self.words.get(word.lower()), :]

    def __init__(self, words, X):
        self.words = words
        self.inverse_words = {value: key for key, value in words.items()}
        self.X = np.array(X)

# %%
dep_model = load_model('deps.words')
bow2_model = load_model('bow2.words')
bow5_model = load_model('bow5.words')
simlex = read_simlex('./SimLex-999/SimLex-999.txt')

# %%
# Calculate similarities
dep_model_similaraties = [
    dep_model.similarity(s['word1'], s['word2'])
    for s in simlex
    if s
]
bow2_model_similaraties = [
    bow2_model.similarity(s['word1'], s['word2'])
    for s in simlex
    if s
]
bow5_model_similaraties = [
    bow5_model.similarity(s['word1'], s['word2'])
    for s in simlex
    if s
]

# %%
# Correlations
print('PEARSON CORRELATION: DEPENDECY MODEL',
      pearsonr(np.array(dep_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))

print('SPEARMAN CORRELATION: DEPENDENCY MODEL',
      spearmanr(np.array(dep_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))

print('PEARSON CORRELATION: BOW 2',
      pearsonr(np.array(bow2_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))

print('SPEARMAN CORRELATION: BOW 2',
      spearmanr(np.array(bow2_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))

print('PEARSON CORRELATION: BOW 5',
      pearsonr(np.array(bow5_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))

print('SPEARMAN CORRELATION: BOW 5',
      spearmanr(np.array(bow5_model_similaraties),
      np.array([s['similarity'] for s in simlex if s])))
# Out:
# PEARSON CORRELATION: DEPENDECY MODEL (0.46290582063062491, 3.3567413263794563e-54)
# SPEARMAN CORRELATION: DEPENDENCY MODEL SpearmanrResult(correlation=0.44669483973233365, pvalue=3.6860379333912496e-50)
# PEARSON CORRELATION: BOW 2 (0.42980946273743831, 3.5436336245595514e-46)
# SPEARMAN CORRELATION: BOW 2 SpearmanrResult(correlation=0.41530352363175638, pvalue=6.2433655846988739e-43)
# PEARSON CORRELATION: BOW 5 (0.3770514946690452, 4.2126873407041235e-35)
# SPEARMAN CORRELATION: BOW 5 SpearmanrResult(correlation=0.36870226791085553, pvalue=1.5844564441079533e-33)

# %%
dep_model_similaraties = [
    dep_model.similarity(s['word1'], s['word2'])
    for s in men
    if s
]
bow2_model_similaraties = [
    bow2_model.similarity(s['word1'], s['word2'])
    for s in men
    if s
]
bow5_model_similaraties = [
    bow5_model.similarity(s['word1'], s['word2'])
    for s in men
    if s
]

# %%
print('PEARSON CORRELATION: DEPENDECY MODEL',
      pearsonr(np.array(dep_model_similaraties),
      np.array([s['similarity'] for s in men if s])))

print('SPEARMAN CORRELATION: DEPENDENCY MODEL',
      spearmanr(np.array(dep_model_similaraties),
      np.array([s['similarity'] for s in men if s])))

print('PEARSON CORRELATION: BOW 2',
      pearsonr(np.array(bow2_model_similaraties),
      np.array([s['similarity'] for s in men if s])))

print('SPEARMAN CORRELATION: BOW 2',
      spearmanr(np.array(bow2_model_similaraties),
      np.array([s['similarity'] for s in men if s])))

print('PEARSON CORRELATION: BOW 5',
      pearsonr(np.array(bow5_model_similaraties),
      np.array([s['similarity'] for s in men if s])))

print('SPEARMAN CORRELATION: BOW 5',
      spearmanr(np.array(bow5_model_similaraties),
      np.array([s['similarity'] for s in men if s])))
# Out:
# PEARSON CORRELATION: DEPENDECY MODEL (0.36515491440061232, 2.7338430277279257e-95)
# SPEARMAN CORRELATION: DEPENDENCY MODEL SpearmanrResult(correlation=0.38953128621479505, pvalue=2.7619770767434266e-109)
# PEARSON CORRELATION: BOW 2 (0.44668931892659725, 4.2271988446707901e-147)
# SPEARMAN CORRELATION: BOW 2 SpearmanrResult(correlation=0.42599024921870665, pvalue=1.4932778282706141e-132)
# PEARSON CORRELATION: BOW 5 (0.52044550878294626, 6.2682928980843816e-208)
# SPEARMAN CORRELATION: BOW 5 SpearmanrResult(correlation=0.44962049199435339, pvalue=3.0410167502527765e-149)

# %%
## ANALOGIES
def batch_analogy(model, analogies):
    A = np.array([model.get(a['a']) for a in analogies])
    B = np.array([model.get(a['b']) for a in analogies])
    C = np.array([model.get(a['c']) for a in analogies])
    D = [model.words.get(a['d'].lower()) for a in analogies]

    new_vector = (B - A) + C
    
    new_vector = np.array([
        row / np.linalg.norm(row) for row
        in new_vector
    ])

    indices = np.argsort(model.X @ new_vector.T, axis=0)[::-1]
    return [np.where(row == d_index)[0][0] for d_index, row in zip(D, indices.T)]

def accuracy(ranking):
    return sum([r for r in ranking if r == 1]) / len(ranking)

def mmr(ranking):
    return sum([1/r for r in ranking if r != 0]) / len(ranking)
    

analogies = [l for l in read_analogies('./analogies.txt') if l]
ranking = batch_analogy(dep_model, analogies[:100])

print('acc: dep model', accuracy(ranking))
print('mmr: dep model', mmr(ranking))

ranking = batch_analogy(bow2_model, analogies[:100])
print('acc: bow2 model', accuracy(ranking))
print('mmr: bow2 model', mmr(ranking))

ranking = batch_analogy(bow5_model, analogies[:100])

print('acc: bow5 model', accuracy(ranking))
print('mmr: bow5 model', mmr(ranking))
# Out:
# acc: dep model 0.06
# mmr: dep model 0.309399532518
# acc: bow2 model 0.54
# mmr: bow2 model 0.623466845525
# acc: bow5 model 0.72
# mmr: bow5 model 0.763333333333

# %%
from sklearn.cluster import KMeans

def read_nouns(file_name):
    with open(file_name, 'r') as file:
        return [
            line.strip() for line in file
        ]

def get_vector(word, model):
    word_index = model.words.get(word)
    return False if not word_index else np.array(model.X[word_index, :])

# %%
# Qualitative Analysis 
cluster_model = KMeans(n_clusters=20, random_state=0)
nouns = read_nouns('nouns.txt')

vectors = [get_vector(w, dep_model) for w in nouns]
dep_nouns_X = [v for v in vectors if v is not False]
dep_k_means_fit = cluster_model.fit_predict(dep_nouns_X)

cluster = [word for word, cluster in zip(nouns, dep_k_means_fit) if cluster == 2]
print('Cluster example dependecy model', cluster)

vectors = [get_vector(w, bow2_model) for w in nouns]
bow2_nouns_X = [v for v in vectors if v is not False]
bow2_k_means_fit = cluster_model.fit_predict(bow2_nouns_X)

cluster = [word for word, cluster in zip(nouns, bow2_k_means_fit) if cluster == 2]
print('Cluster example bow2 model', cluster)

vectors = [get_vector(w, bow5_model) for w in nouns]
bow5_nouns_X = [v for v in vectors if v is not False]
bow5_k_means_fit = cluster_model.fit_predict(bow5_nouns_X)

cluster = [word for word, cluster in zip(nouns, bow5_k_means_fit) if cluster == 2]
print('Cluster example dependecy model', cluster)
# Out:
# Cluster example dependecy model ['aircraft', 'battery', 'bike', 'boat', 'bomb', 'boom', 'button', 'cable', 'camera', 'card', 'carriage', 'carrier', 'cell', 'chip', 'clock', 'computer', 'container', 'craft', 'crew', 'deck', 'device', 'disc', 'disk', 'engine', 'envelope', 'equipment', 'film', 'fragment', 'gaze', 'guilt', 'helen', 'instruction', 'interest', 'lack', 'lamb', 'lord', 'lunch', 'machine', 'magistrate', 'meat', 'memory', 'mirror', 'model', 'motive', 'mountain', 'order', 'pace', 'pack', 'package', 'passage', 'philosophy', 'plan', 'plate', 'process', 'raid', 'scott', 'shadow', 'shift', 'sofa', 'staff', 'talk', 'tank', 'taste', 'teenager', 'tony', 'trail', 'trousers', 'truth', 'variety', 'version', 'view', 'wealth', 'west', 'winter']
# Cluster example bow2 model ['anger', 'anxiety', 'atmosphere', 'attitude', 'audience', 'awareness', 'background', 'beauty', 'breath', 'chaos', 'christ', 'comfort', 'confusion', 'consciousness', 'conversation', 'curiosity', 'danger', 'darkness', 'delight', 'dialogue', 'dream', 'emotion', 'enthusiasm', 'excitement', 'experience', 'expression', 'faith', 'fate', 'fear', 'feeling', 'finance', 'flat', 'friend', 'fruit', 'gate', 'germany', 'glass', 'glimpse', 'guideline', 'gulf', 'handle', 'heap', 'heat', 'helicopter', 'hook', 'horn', 'howard', 'identification', 'image', 'insider', 'instance', 'japan', 'knot', 'laugh', 'licence', 'loss', 'membership', 'million', 'month', 'music', 'mystery', 'nation', 'page', 'panel', 'passenger', 'percentage', 'person', 'philip', 'player', 'pleasure', 'poet', 'practitioner', 'price', 'radio', 'reading', 'referendum', 'relief', 'reward', 'selection', 'seller', 'sensation', 'sense', 'side', 'sigh', 'significance', 'skirt', 'slope', 'smell', 'sort', 'soul', 'spine', 'stuff', 'task', 'territory', 'thing', 'thomas', 'title', 'total', 'traffic', 'trophy', 'trustee', 'uncertainty', 'unit', 'village', 'violence', 'virus', 'visitor', 'ward', 'wave']
# Cluster example dependecy model ['aircraft', 'barrel', 'basket', 'bath', 'bathroom', 'battery', 'bedroom', 'bell', 'bench', 'bike', 'blanket', 'boat', 'boot', 'bottom', 'brick', 'brush', 'bucket', 'bull', 'camera', 'candle', 'carpet', 'carriage', 'ceiling', 'chain', 'chamber', 'chip', 'cigarette', 'clock', 'cloth', 'coffin', 'coin', 'container', 'craft', 'crew', 'cupboard', 'curtain', 'custom', 'deck', 'door', 'doorway', 'downstairs', 'engine', 'equipment', 'fabric', 'factory', 'fence', 'flame', 'flood', 'fragment', 'friendship', 'fund', 'gang', 'gaze', 'glance', 'grip', 'health', 'holder', 'holding', 'horizon', 'horror', 'incentive', 'interface', 'kiss', 'lack', 'lamb', 'location', 'lord', 'lunch', 'machine', 'manner', 'message', 'motive', 'mountain', 'nerve', 'order', 'pace', 'pain', 'palm', 'paul', 'piece', 'pile', 'pint', 'plant', 'pond', 'rome', 'roof', 'scott', 'script', 'shadow', 'sheep', 'sheet', 'shelf', 'shell', 'shift', 'shock', 'shoe', 'slice', 'society', 'stage', 'statistics', 'stomach', 'talk', 'tank', 'tension', 'tide', 'traveller', 'trousers', 'truth', 'variety', 'version', 'walker', 'west', 'wind', 'wine', 'winter', 'woman']

# %%
from sklearn.manifold import TSNE

tsne = TSNE()
transformed_dep = tsne.fit_transform(dep_nouns_X)

tsne = TSNE()
transformed_bow2 = tsne.fit_transform(bow2_nouns_X)

tsne = TSNE()
transformed_bow5 = tsne.fit_transform(bow5_nouns_X)

# %%
import matplotlib.pyplot as plt
import random

def random_color():
    return (
        random.random(),
        random.random(),
        random.random()
    )

colors = [random_color() for _ in range(20)]

plt.scatter(transformed_dep[:, 0], transformed_dep[:, 1], s=10, c=[colors[i] for i in dep_k_means_fit])
plt.rcParams['figure.figsize'] = [30, 14]
plt.title('Dependency model clusters')
plt.show()

# %%
colors = [random_color() for _ in range(20)]

plt.scatter(transformed_bow2[:, 0], transformed_bow2[:, 1], s=10, c=[colors[i] for i in bow2_k_means_fit])
plt.rcParams['figure.figsize'] = [30, 14]
plt.title('bow2 model clusters')
plt.show()

# %%
colors = [random_color() for _ in range(20)]

plt.scatter(transformed_bow5[:, 0], transformed_bow5[:, 1], s=10, c=[colors[i] for i in bow5_k_means_fit])
plt.rcParams['figure.figsize'] = [30, 14]
plt.title('bow5 model clusters')
plt.show()
